# %%
import pandas as pd

# %%
page_activations_df = pd.read_pickle("activations_cassandra.pickle")

# %%
page_activations_df.head()
# Out:
#    page_id          visit_time  count
# 0      734 2018-07-31 22:00:00     14
# 1      734 2018-07-31 23:00:00      8
# 2      734 2018-08-01 00:00:00      7
# 3      734 2018-08-01 01:00:00     11
# 4      734 2018-08-01 02:00:00     14

# %%
page_activations_df.shape
# Out:
# (2589123, 3)

# %%
page_activations_df.set_index('visit_time', inplace=True)

# %%
page_activations_groupby = page_activations_df.groupby('page_id')

# %%
page_activations_groupby.head()
# Out:
#                       page_id  count
# visit_time
# 2018-07-31 22:00:00       734     14
# 2018-07-31 23:00:00       734      8
# 2018-08-01 00:00:00       734      7
# 2018-08-01 01:00:00       734     11
# 2018-08-01 02:00:00       734     14
# 2018-08-01 22:00:00       887      4
# 2018-08-02 00:00:00       887      1
# 2018-08-02 03:00:00       887      3
# 2018-08-02 04:00:00       887      1
# 2018-08-02 05:00:00       887      4
# 2018-08-02 22:00:00      1088      3
# 2018-08-02 23:00:00      1088      3
# 2018-08-03 00:00:00      1088      3
# 2018-08-03 01:00:00      1088      8
# 2018-08-03 02:00:00      1088      6
# 2018-08-05 22:00:00      1175      2
# 2018-08-05 23:00:00      1175      2
# 2018-08-06 00:00:00      1175      5
# 2018-08-06 01:00:00      1175      2
# 2018-08-06 02:00:00      1175      2
# 2018-08-01 22:00:00      1200      1
# 2018-08-01 23:00:00      1200      7
# 2018-08-02 01:00:00      1200      5
# 2018-08-02 02:00:00      1200      3
# ...
